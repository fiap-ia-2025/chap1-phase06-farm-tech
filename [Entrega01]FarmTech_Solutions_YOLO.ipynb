# %% [markdown]
# Conectar com google drive

# %% [markdown]
# Pastas https://drive.google.com/drive/folders/1WLe_Iwy2RCa5MSCHE2sDJgeLfuxUh-B9?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Baixar o Repositório YOLOv5 e Instalar Dependências

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17608, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17608 (delta 7), reused 2 (delta 2), pack-reused 17593 (from 2)
# Receiving objects: 100% (17608/17608), 16.82 MiB | 23.28 MiB/s, done.
# Resolving deltas: 100% (11983/11983), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Configuração do Dataset

# %%
# %%writefile data.yaml
# # Este comando cria o arquivo 'data.yaml' temporariamente na pasta do YOLOv5 no Colab
#
# train: /content/drive/MyDrive/ColabNotebooks/Cap_1/train
# val: /content/drive/MyDrive/ColabNotebooks/Cap_1/validation
# test: /content/drive/MyDrive/ColabNotebooks/Cap_1/test
#
# nc: 2
# names: ['cow', 'sheep']
# Out:
# Writing data.yaml

# %% [markdown]
# Treinamento do modelo

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data data.yaml --weights yolov5s.pt --name YOLO_Simulacao_30_Epocas
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-12 21:44:21.078055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760305461.103814     917 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data data.yaml --weights yolov5s.pt --name YOLO_Simulacao_60_Epocas
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-12 22:36:11.136406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760308571.434308   13773 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760308571.511462   13773 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760308572.077962   13773 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# Validação do Teste

# %%
# !python detect.py --weights /content/yolov5/runs/train/YOLO_Simulacao_60_Epocas/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/ColabNotebooks/Cap_1/test
# Out:
# detect: weights=['/content/yolov5/runs/train/YOLO_Simulacao_60_Epocas/weights/best.pt'], source=/content/drive/MyDrive/ColabNotebooks/Cap_1/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/ColabNotebooks/Cap_1/test/1.jpg: 448x640 1 cow, 282.9ms
# image 2/8 /content/drive/MyDrive/ColabNotebooks/Cap_1/test/2.jpg: 448x640 1 cow, 343.6ms
# ...
